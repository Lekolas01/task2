# %%
import csv
import string

filename = "generalization"
f_train_pos = open(filename+".f", "w")
f_train_neg = open(filename+".n", "w")

with open('training_dataset.csv', 'r') as file:
    reader = csv.reader(file)
    names = next(reader)[:-1]   
    for row in reader:
        if row[-1] == "Bad":
            f_train_neg.write(filename+"("+",".join(row[:-1])+").\n")
        else:
            f_train_pos.write(filename+"("+",".join(row[:-1])+").\n")
f_train_pos.close()
f_train_neg.close()

f_test_pos = open(filename+"_test.f", "w")
f_test_neg = open(filename+"_test.n", "w")

with open('testing_dataset.csv', 'r') as file:
    reader = csv.reader(file)
    names = next(reader)[:-1]   
    for row in reader:
        if row[-1] == "Bad":
            f_test_pos.write(filename+"("+",".join(row[:-1])+").\n")
        else:
            f_test_neg.write(filename+"("+",".join(row[:-1])+").\n")
f_test_pos.close()
f_test_neg.close()

f_background = open(filename+"_background.txt", "w")
store = {}
with open('training_dataset.csv', 'r') as file:
    reader = csv.reader(file)
    names = next(reader)[:-1] 
      
    for row in reader:
        for att, val in zip(names, row[:-1]):
            try:
                store[att].add(val)
            except KeyError:
                store[att] = {val}
                
for key in store.keys():
    #print(key)
    for value in store[key]:
        f_background.write(key+"("+value+").\n")
f_background.close()
# Out:
# Att1
# A12
# A13
# A11
# A14
# Att2
# 7
# 13
# 5
# 72
# 28
# 12
# 42
# 21
# 40
# 16
# 9
# 20
# 10
# 60
# 4
# 54
# 45
# 24
# 18
# 22
# 26
# 11
# 8
# 36
# 39
# 30
# 48
# 6
# 33
# 14
# 15
# 27
# Att3
# A32
# A30
# A33
# A31
# A34
# Att4
# A45
# A42
# A410
# A46
# A43
# A41
# A49
# A44
# A40
# A48
# Att6
# A63
# A62
# A61
# A64
# A65
# Att7
# A74
# A72
# A73
# A75
# A71
# Att8
# 2
# 4
# 3
# 1
# Att9
# A91
# A92
# A93
# A94
# Att10
# A103
# A102
# A101
# Att12
# A122
# A123
# A121
# A124
# Att14
# A143
# A142
# A141
# Att15
# A152
# A151
# A153
# Att17
# A174
# A171
# A173
# A172
# Att18
# 2
# 1
# Att19
# A192
# A191
# Att20
# A202
# A201
